# %% [markdown]
# ![image.png](attachment:81b3ac19-ba33-4a3f-ab0a-d6aff6b4e22e.png)

# %%
# declare the variables and get inputs from user
p = float(input("Enter the principal amount: "))
m = float(input("How much do you deposit periodically: "))
t = float(input("Enter the amount of years: "))
r = float(input("Enter the interest rate: "))
n = float(input("Enter the number of times the interest is compounded per year: "))

# Calulating the annuity plan
a = p * m * t * ((1 + r / n) ** (n * t) - 1) / (r / n)

# Displaying the annuity plan
print(f"The Annuity Plan is {a:.2f}")
# Out:
# Enter the principal amount:  120000
# How much do you deposit periodically:  2000
# Enter the amount of years:  4
# Enter the interest rate:  2
# Enter the number of times the interest is compounded per year:  2
# The Annuity Plan is 244800000000.00
